# %%
import torch
from ultralytics import YOLO

# %% [markdown]
# bumble_bee-wasps-bee-dataset.v2i.yolo

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Cell for resuming training.

# %%
model = YOLO(R"C:\Users\Bas_K\source\repos\Thesis\thesis-insect-monitoring\runs\detect\bumble_bee-wasps-bee-dataset.yolov26x\100epochs_imgsz640_patience30\weights\last.pt")
results = model.train(resume=True)
model.val(data=R"D:\datasets\bumble_bee-wasps-bee-dataset.v2i.yolo\data.yaml", split="test", project="bumble_bee-wasps-bee-dataset.yolov26x", name="val_100epochs_imgsz640_patience30")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model = YOLO(R"C:\Users\Bas_K\source\repos\Thesis\thesis-insect-monitoring\runs\detect\bumble_bee-wasps-bee-dataset.yolov26x\100epochs_imgsz640_patience30\weights\last.pt")
#       2 results = model.train(resume=True)
#       3 model.val(data=R"D:\datasets\bumble_bee-wasps-bee-dataset.v2i.yolo\data.yaml", split="test", project="bumble_bee-wasps-bee-dataset.yolov26x", name="val_100epochs_imgsz640_patience30")
#
# NameError: name 'YOLO' is not defined

# %% [markdown]
# bumble_bee-wasps-bee-dataset.yolo

# %%
model = YOLO("yolo11x.pt")
results = model.train(data=R"D:\datasets\bumble_bee-wasps-bee-dataset.v2i.yolo\data.yaml", epochs=100, patience=30, imgsz=640, save_period=10, project="bumble_bee-wasps-bee-dataset.yolov11x", name="100epochs_imgsz640_patience30", plots=True)
model.val(data=R"D:\datasets\bumble_bee-wasps-bee-dataset.v2i.yolo\data.yaml", split="test")
# Out:
# New https://pypi.org/project/ultralytics/8.4.32 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.23  Python-3.12.7 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
model = YOLO("yolov8x.pt")
results = model.train(data=R"D:\datasets\bumble_bee-wasps-bee-dataset.v2i.yolo\data.yaml", epochs=100, patience=30, imgsz=640, save_period=10, project="bumble_bee-wasps-bee-dataset.yolov8x", name="100epochs_imgsz640_patience30", plots=True)
model.val(data=R"D:\datasets\bumble_bee-wasps-bee-dataset.v2i.yolo\data.yaml", split="test")
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.32 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.23  Python-3.12.7 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
model = YOLO("yolo26x.pt")
results = model.train(data=R"D:\datasets\bumble_bee-wasps-bee-dataset.v2i.yolo\data.yaml", epochs=100, patience=30, imgsz=640, save_period=10, project="bumble_bee-wasps-bee-dataset.yolov26x", name="100epochs_imgsz640_patience30", plots=True)
model.val(data=R"D:\datasets\bumble_bee-wasps-bee-dataset.v2i.yolo\data.yaml", split="test", project="bumble_bee-wasps-bee-dataset.yolov26x", name="val_100epochs_imgsz640_patience30")
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.33 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.23  Python-3.12.7 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %% [markdown]
# bees.v1i.yolo

# %%
model = YOLO("yolo11x.pt")
results = model.train(data=R"D:\datasets\bees.v1i.yolo\data.yaml", epochs=100, patience=30, imgsz=640, save_period=10, project="bees.yolov11x", name="100epochs_imgsz640_patience30", plots=True)
model.val(data=R"D:\datasets\bees.v1i.yolo\data.yaml", split="test")

# %%
model = YOLO("yolo8x.pt")
results = model.train(data=R"D:\datasets\bees.v1i.yolo\data.yaml", epochs=100, patience=30, imgsz=640, save_period=10, project="bees.yolov8x", name="100epochs_imgsz640_patience30", plots=True)
model.val(data=R"D:\datasets\bees.v1i.yolo\data.yaml", split="test")

# %%
model = YOLO("yolo26x.pt")
results = model.train(data=R"D:\datasets\bees.v1i.yolo\data.yaml", epochs=100, patience=30, imgsz=640, save_period=10, project="bees.yolov26x", name="100epochs_imgsz640_patience30", plots=True)
model.val(data=R"D:\datasets\bees.v1i.yolo\data.yaml", split="test")
